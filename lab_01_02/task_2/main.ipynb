# %%
import scipy.linalg
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import math
# %matplotlib inline

# %%
fig, ax = plt.subplots()
x = np.arange(1, 15, 0.1)
y = np.sin(x / 5) * np.exp(x / 10) + 5 * np.exp(-x / 2)
ax.plot(x, y)
plt.show()

# %%
def func(x):
    return np.sin(x / 5) * np.exp(x / 10) + 5 * np.exp(-x / 2)

A = np.array([[1., 1.], [1., 15.]])
b = np.array([func(1.), func(15.)])
x = scipy.linalg.solve(A, b)
fig, ax = plt.subplots()
ax.plot(x, polinom(x))
plt.show()
print(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-4ba5a82dc787> in <module>
#       6 x = scipy.linalg.solve(A, b)
#       7 fig, ax = plt.subplots()
# ----> 8 ax.plot(x, polinom(x))
#       9 plt.show()
#      10 print(x)
#
# <ipython-input-15-e8060ec5c22b> in polinom(x)
#       1 def polinom(x):
#       2     # Yi = solve * Xi where Xi = x^i
# ----> 3     tiles = np.tile(x, (n, 1))
#       4     tiles[0] = np.ones(x.size)
#       5     for index in range(1, n):
#
# NameError: name 'n' is not defined

# %%
A = np.array([[1., 1., 1.], [1., 8., 64.], [1., 15., 225.]])
b = np.array([func(1.), func(8), func(15.)])
x = scipy.linalg.solve(A, b)
fig, ax = plt.subplots()
ax.plot(x, func(x))
plt.show()
print(x)
# Out:
# [ 3.32512949 -0.06531159 -0.00760104]

# %%
A = np.array([[1., 1., 1., 1.], [1., 4**1., 4**2., 4**3.], [1., 10**1., 10**2., 10**3.], [1., 15., 225., 15**3.]])
b = np.array([func(1.), func(4), func(10), func(15.)])
x = scipy.linalg.solve(A, b)
print(x)
print(func(x))
fig, ax = plt.subplots()

ax.plot(x, func(x))
plt.show()
# Out:
# [ 4.36264154 -1.29552587  0.19333685 -0.00823565]
# [1.74933353 9.33121961 4.5786973  5.0189858 ]

# %%
file = open("ans.txt", "w")
for i in x:
    file.write(str(i) + ' ')
